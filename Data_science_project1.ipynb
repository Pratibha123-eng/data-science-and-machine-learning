# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratibha123-eng/data-science-and-machine-learning/blob/main/Data_science_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Covid 19 in italy data analysis

# %% [markdown]
# importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"covid19_italy_region.csv")

# %%
data.head()
data.shape
# Out:
# (6027, 17)

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.tail()
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 6022  6022  2020-12-06T17:00:00     ITA          19        Sicilia  38.115697
# 6023  6023  2020-12-06T17:00:00     ITA           9        Toscana  43.769231
# 6024  6024  2020-12-06T17:00:00     ITA          10         Umbria  43.106758
# 6025  6025  2020-12-06T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 6026  6026  2020-12-06T17:00:00     ITA           5         Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 6022  13.362357                  1367                    213
# 6023  11.255889                  1360                    252
# 6024  12.388247                   332                     60
# 6025   7.320149                   102                      8
# 6026  12.338452                  2508                    308
#
#       TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# ...

# %%
data.describe()
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  6027.000000  6027.000000  6027.000000  6027.000000
# mean   3013.000000    11.857143    43.046293    12.225955
# std    1739.989368     6.274319     2.488987     2.659168
# min       0.000000     1.000000    38.115697     7.320149
# 25%    1506.500000     7.000000    41.125596    11.121231
# 50%    3013.000000    12.000000    43.616760    12.388247
# 75%    4519.500000    17.000000    45.434905    13.768136
# max    6026.000000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           6027.000000            6027.000000                6027.000000
# mean             509.093579              55.892318                 564.985897
# std             1272.731157             134.957979                1403.362341
# min                0.000000               0.000000                   0.000000
# ...

# %%
data.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %% [markdown]
# scatter plot

# %%
sns.scatterplot(data=data,x="TotalPositiveCases",y="Recovered")
# Out:
# <Axes: xlabel='TotalPositiveCases', ylabel='Recovered'>

# %% [markdown]
# conclusion from graph:- total positive cases is more initally but after some time the revored people are more than total cases.

# %%
sns.relplot(data=data,x="TotalPositiveCases",y="HomeConfinement")

# %%
sns.scatterplot(data=data,x="TotalPositiveCases",y="TestsPerformed",hue="RegionName")
# Out:
# <Axes: xlabel='TotalPositiveCases', ylabel='TestsPerformed'>

# %%
sns.scatterplot(data=data,x="TotalPositiveCases",y="TotalHospitalizedPatients",hue="Recovered")
# Out:
# <Axes: xlabel='TotalPositiveCases', ylabel='TotalHospitalizedPatients'>

# %% [markdown]
# pair plot

# %%
sns.pairplot(data)

# %% [markdown]
# Line plot

# %%
sns.lineplot(data=data,x="TestsPerformed",y="TotalPositiveCases",hue ="RegionName")
# Out:
# <Axes: xlabel='TestsPerformed', ylabel='TotalPositiveCases'>

# %% [markdown]
# categorial plot

# %%
g = sns.catplot(data=data,x="RegionName",y="TotalPositiveCases",hue="TestsPerformed",kind="bar")
g.set_xticklabels(rotation=90)
