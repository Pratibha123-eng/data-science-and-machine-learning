# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratibha123-eng/data-science-and-machine-learning/blob/support-vector-machine/bangolre_house_prediction_SVR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # load dataset

# %%
import pandas as pd
import numpy as np
path=r"https://drive.google.com/uc?export=download&id=1xxDtrZKfuWQfl-6KA9XEd_eatitNPnkB"
df=pd.read_csv(path)
df.head()
df.tail()
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 7115   3.0      2.0  325.00          2900.0    3    11206.896552
# 7116   3.0      1.0   84.83          1780.0    3     4765.730337
# 7117   2.0      1.0   48.00           880.0    2     5454.545455
# 7118   2.0      1.0   55.00          1000.0    2     5500.000000
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 7115                              1                        0
# 7116                              1                        0
# 7117                              0                        0
# 7118                              0                        0
# 7119                              0                        0
#
#       area_typePlot  Area  availability_Ready To Move  ...  \
# 7115                    0                           1  ...
# 7116                    0                           0  ...
# ...

# %%
X=df.drop('price',axis=1)
y=df['price']
print("shape of x",X.shape)
print("shape of y",y.shape)
# Out:
# shape of x (7120, 107)
# shape of y (7120,)

# %% [markdown]
# # train and split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=2,random_state=51)
print("shape of X_train",X_train.shape)
print("shape of Y_train",y_train.shape)
print("shape of X_test",X_test.shape)
print("shape of y_test",y_test.shape)
# Out:
# shape of X_train (7118, 107)
# shape of Y_train (7118,)
# shape of X_test (2, 107)
# shape of y_test (2,)

# %% [markdown]
# # feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X_train)
X_train_sc=sc.transform(X_train)
X_test_sc=sc.transform(X_test)

# %% [markdown]
# # svr- rbf

# %%
from sklearn.svm import SVR
from sklearn.metrics import r2_score
svr=SVR(kernel='rbf')
svr.fit(X_train_sc,y_train)
y_pred=svr.predict(X_test_sc)
r2_score(y_test,y_pred)
# Out:
# 0.22202102894419828

# %% [markdown]
# # svr- linear

# %%
svr=SVR(kernel='linear')
svr.fit(X_train_sc,y_train)
y_pred=svr.predict(X_test_sc)
r2_score(y_test,y_pred)
# Out:
# 0.8868708808774299

# %% [markdown]
# # svr-polynomial

# %%
svr=SVR(kernel='poly',degree=2)
svr.fit(X_train_sc,y_train)
y_pred=svr.predict(X_test_sc)
r2_score(y_test,y_pred)
# Out:
# 0.24023441656232947

# %% [markdown]
# price prediction

# %%
svr=SVR(kernel='linear')
svr.fit(X_train_sc,y_train)
y_pred=svr.predict(X_test_sc)
y_pred
# Out:
# array([86.48009603, 33.03496943])

# %%
y_test
# Out:
# 2435    80.0
# 3113    40.0
# Name: price, dtype: float64

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9366308082386671

# %% [markdown]
# # root mean square error

# %%
from sklearn.metrics import mean_squared_error
import math
mse=mean_squared_error(y_test,y_pred)
rmse=math.sqrt(mse)
mse
# Out:
# 45.251647649028044

# %%
rmse
# Out:
# 6.7269344912098
