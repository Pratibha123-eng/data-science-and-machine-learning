# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratibha123-eng/data-science-and-machine-learning/blob/naive-bayes/Naive_Bayas_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_breast_cancer
data=load_breast_cancer()
df=pd.DataFrame(np.c_[data.data,data.target],columns=[list(data.feature_names)+['target']])

# %%
df.head()
# Out:
#   mean radius mean texture mean perimeter mean area mean smoothness  \
# 0       17.99        10.38         122.80    1001.0         0.11840
# 1       20.57        17.77         132.90    1326.0         0.08474
# 2       19.69        21.25         130.00    1203.0         0.10960
# 3       11.42        20.38          77.58     386.1         0.14250
# 4       20.29        14.34         135.10    1297.0         0.10030
#
#   mean compactness mean concavity mean concave points mean symmetry  \
# 0          0.27760         0.3001             0.14710        0.2419
# 1          0.07864         0.0869             0.07017        0.1812
# 2          0.15990         0.1974             0.12790        0.2069
# 3          0.28390         0.2414             0.10520        0.2597
# 4          0.13280         0.1980             0.10430        0.1809
#
#   mean fractal dimension  ... worst texture worst perimeter worst area  \
# 0                0.07871  ...         17.33          184.60     2019.0
# ...

# %%
X= df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2020)

# %% [markdown]
# # gaussian naive bayas

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
gnb.score(X_test,y_test)
# Out:
# 0.9736842105263158

# %% [markdown]
# # multinomial bayas

# %%
from sklearn.naive_bayes import MultinomialNB
mnb=MultinomialNB()
mnb.fit(X_train,y_train)
mnb.score(X_test,y_test)
# Out:
# 0.8947368421052632

# %% [markdown]
# # bernolli naive bayas

# %%
from sklearn.naive_bayes import BernoulliNB
bnb=BernoulliNB()
bnb.fit(X_train,y_train)
bnb.score(X_test,y_test)
# Out:
# 0.5789473684210527

# %%
patient1=[17.99,
 10.38,
 122.8,
 1001.0,
 0.1184,
 0.2776,
 0.3001,
 0.1471,
 0.2419,
 0.07871,
 1.095,
 0.9053,
 8.589,
 153.4,
 0.006399,
 0.04904,
 0.05373,
 0.01587,
 0.03003,
 0.006193,
 25.38,
 17.33,
 184.6,
 2019.0,
 0.1622,
 0.6656,
 0.7119,
 0.2654,
 0.4601,
 0.1189]

# %%
patiennt1_sc=np.array([patient1])

# %%
y_pred1=gnb.predict(patiennt1_sc)
y_pred1
# Out:
# array([0.])

# %%
y_pred2=mnb.predict(patiennt1_sc)
y_pred2
# Out:
# array([0.])

# %%
y_pred3=bnb.predict(patiennt1_sc)
y_pred3
# Out:
# array([1.])
